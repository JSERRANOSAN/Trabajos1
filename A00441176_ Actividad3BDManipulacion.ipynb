# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# NOMBRE: ----Jesús Antonio Serrano Sánchez--------------------
#
# MATRÍCULA: ----A00441176-------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.10/dist-packages (1.1.0)

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` y una conexión con `connect()` como se muestra a continuación:

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.157.52:3306/classicmodels', pool_recycle=3600)

# Crea una conexión para luego invocar declaraciones SQL
conn = db.connect()

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
#con un query, atraigo la información y genero la consulta de las líneas de productos
query = sqla.text('SELECT * FROM productlines')
df = pd.read_sql(query, conn)
df
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# 3.	Los empleados ordenados por nombre.

# %%
query =sqla.text('SELECT lastName,	firstName FROM employees  ORDER BY lastName')
df=pd.read_sql(query, conn)
df
# Out:
#      lastName firstName
# 0      Bondur    Gerard
# 1      Bondur      Loui
# 2        Bott     Larry
# 3         Bow   Anthony
# 4    Castillo    Pamela
# 5    Firrelli      Jeff
# 6    Firrelli     Julie
# 7      Fixter      Andy
# 8      Gerard    Martin
# 9   Hernandez    Gerard
# 10   Jennings    Leslie
# 11      Jones     Barry
# 12       Kato   Yoshimi
# 13       King       Tom
# 14      Marsh     Peter
# 15     Murphy     Diane
# 16      Nishi      Mami
# 17  Patterson      Mary
# 18  Patterson     Steve
# 19  Patterson   William
# 20   Thompson    Leslie
# 21      Tseng  Foon Yue
# 22     Vanauf    George

# %% [markdown]
# 4.	Los países donde hay oficinas.

# %%
query =sqla.text('SELECT DISTINCT country FROM offices  ORDER BY country')
df=pd.read_sql(query, conn)
df
# Out:
#      country
# 0  Australia
# 1     France
# 2      Japan
# 3         UK
# 4        USA

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de Nueva York (*NYC*).

# %%
#el nombre y teléfono de los clientes de Nueva York (NYC)
query =sqla.text('SELECT customerName, phone  FROM customers  WHERE city = "NYC"')
df=pd.read_sql(query, conn)
df
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 1000 unidades en stock.

# %%
query = sqla.text("SELECT productCode, productName FROM products WHERE ProductVendor = 'Gearbox Collectibles' AND quantityInStock < 1000")
df = pd.read_sql(query, conn)
df
# Out:
#   productCode             productName
# 0    S18_2581          P-51-D Mustang
# 1    S18_2795  1928 Mercedes-Benz SSK

# %% [markdown]
# 7.	Los tres productos más caros, desde el punto de visto de los comercializadores (`buyPrice`).

# %%
query = sqla.text("SELECT * FROM products ORDER BY buyPrice DESC LIMIT 3")
df = pd.read_sql(query, conn)
df
# Out:
#   productCode                     productName   productLine productScale  \
# 0    S10_4962          1962 LanciaA Delta 16V  Classic Cars         1:10
# 1    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
# 2    S10_1949        1952 Alpine Renault 1300  Classic Cars         1:10
#
#              productVendor                                 productDescription  \
# 0      Second Gear Diecast  Features include: Turnable front wheels; steer...
# 1     Gearbox Collectibles  Turnable front wheels; steering function; deta...
# 2  Classic Metal Creations  Turnable front wheels; steering function; deta...
#
#    quantityInStock  buyPrice    MSRP
# 0             6791    103.42  147.74
# 1             4724    101.51  163.73
# 2             7305     98.58  214.30

# %% [markdown]
# 8.	La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
query = sqla.text('SELECT productLine, COUNT(productCode) FROM productlines JOIN products USING (productLine) GROUP BY productLine')
df = pd.read_sql(query, conn)
df
# Out:
#         productLine  COUNT(productCode)
# 0      Classic Cars                  38
# 1       Motorcycles                  13
# 2            Planes                  12
# 3             Ships                   9
# 4            Trains                   3
# 5  Trucks and Buses                  11
# 6      Vintage Cars                  24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
query = sqla.text('SELECT country, COUNT(employeeNumber) FROM offices JOIN employees USING (officeCode) GROUP BY country')
df = pd.read_sql(query, conn)
df
# Out:
#      country  COUNT(employeeNumber)
# 0  Australia                      4
# 1     France                      5
# 2      Japan                      2
# 3         UK                      2
# 4        USA                     10

# %% [markdown]
# 10.	El promedio de los pagos de cada uno de los clientes de España.

# %%
query = sqla.text("SELECT customerNumber, AVG(amount) FROM customers JOIN payments USING (customerNumber) WHERE country = 'Spain' GROUP BY customerNumber")
df = pd.read_sql(query, conn)
df
# Out:
#    customerNumber   AVG(amount)
# 0             141  55056.844615
# 1             216  22840.156667
# 2             344  23375.570000
# 3             458  37480.030000
# 4             484  25493.925000

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas. Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
productlines= pd.read_sql(sqla.text('SELECT * FROM productlines'), conn)
employees= pd.read_sql(sqla.text('SELECT* FROM employees'), conn)
offices= pd.read_sql(sqla.text('SELECT* FROM offices'), conn)
custumers= pd.read_sql(sqla.text('SELECT* FROM customers'), conn)
payments= pd.read_sql(sqla.text('SELECT* FROM payments'), conn)
products= pd.read_sql(sqla.text('SELECT* FROM products'), conn)

#Obtengo los empleados ordenados por nombre

employees.sort_values(by='lastName')
# Out:
#     employeeNumber   lastName firstName extension  \
# 4             1102     Bondur    Gerard     x5408
# 12            1337     Bondur      Loui     x6493
# 15            1501       Bott     Larry     x2311
# 5             1143        Bow   Anthony     x5428
# 14            1401   Castillo    Pamela     x2759
# 2             1076   Firrelli      Jeff     x9273
# 8             1188   Firrelli     Julie     x2173
# 17            1611     Fixter      Andy      x101
# 22            1702     Gerard    Martin     x2312
# 13            1370  Hernandez    Gerard     x2028
# 6             1165   Jennings    Leslie     x3291
# 16            1504      Jones     Barry      x102
# 21            1625       Kato   Yoshimi      x102
# 19            1619       King       Tom      x103
# 18            1612      Marsh     Peter      x102
# 0             1002     Murphy     Diane     x5800
# 20            1621      Nishi      Mami      x101
# 9             1216  Patterson     Steve     x4334
# 3             1088  Patterson   William     x4871
# 1             1056  Patterson      Mary     x4611
# 7             1166   Thompson    Leslie     x4065
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
#
#                               email officeCode  reportsTo  \
# 4      gbondur@classicmodelcars.com          4     1056.0
# 12     lbondur@classicmodelcars.com          4     1102.0
# 15       lbott@classicmodelcars.com          7     1102.0
# 5         abow@classicmodelcars.com          1     1056.0
# 14   pcastillo@classicmodelcars.com          4     1102.0
# 2    jfirrelli@classicmodelcars.com          1     1002.0
# 8    jfirrelli@classicmodelcars.com          2     1143.0
# 17     afixter@classicmodelcars.com          6     1088.0
# 22     mgerard@classicmodelcars.com          4     1102.0
# 13   ghernande@classicmodelcars.com          4     1102.0
# 6    ljennings@classicmodelcars.com          1     1143.0
# 16      bjones@classicmodelcars.com          7     1102.0
# 21       ykato@classicmodelcars.com          5     1621.0
# 19       tking@classicmodelcars.com          6     1088.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 0      dmurphy@classicmodelcars.com          1        NaN
# 20      mnishi@classicmodelcars.com          5     1056.0
# 9   spatterson@classicmodelcars.com          2     1143.0
# 3   wpatterson@classicmodelcars.com          6     1056.0
# 1    mpatterso@classicmodelcars.com          1     1002.0
# 7    lthompson@classicmodelcars.com          1     1143.0
# 10      ftseng@classicmodelcars.com          3     1143.0
# 11     gvanauf@classicmodelcars.com          3     1143.0
#
#                 jobTitle
# 4    Sale Manager (EMEA)
# 12             Sales Rep
# 15             Sales Rep
# 5     Sales Manager (NA)
# 14             Sales Rep
# 2           VP Marketing
# 8              Sales Rep
# 17             Sales Rep
# 22             Sales Rep
# 13             Sales Rep
# 6              Sales Rep
# 16             Sales Rep
# 21             Sales Rep
# 19             Sales Rep
# 18             Sales Rep
# 0              President
# 20             Sales Rep
# 9              Sales Rep
# 3   Sales Manager (APAC)
# 1               VP Sales
# 7              Sales Rep
# 10             Sales Rep
# 11             Sales Rep

# %%
#Obtengo los países donde hay oficinas
pd.DataFrame(offices['country'].unique())
# Out:
#            0
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %%
#el nombre y teléfono de los clientes de Nueva York (NYC)
custumers[custumers['city'] == 'NYC'][['customerName', 'phone']]
# Out:
#              customerName       phone
# 9       Land of Toys Inc.  2125557818
# 15     Muscle Machine Inc  2125557413
# 27        Vitachrome Inc.  2125551500
# 98   Classic Legends Inc.  2125558493
# 105       Microscale Inc.  2125551957

# %%
#Los tres productos màs caros desde el punto de visto de los comercializadores (buyPrice).

products.nlargest(3, 'buyPrice')[['productCode', 'productName']]
# Out:
#    productCode                     productName
# 5     S10_4962          1962 LanciaA Delta 16V
# 25    S18_2238  1998 Chrysler Plymouth Prowler
# 1     S10_1949        1952 Alpine Renault 1300

# %%
#La cantidad de productos por línea de producto
mergedf = productlines.merge(products, on='productLine')

mergedf
# Out:
#       productLine                                    textDescription  \
# 0    Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1    Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2    Classic Cars  Attention car enthusiasts: Make your wildest c...
# 3    Classic Cars  Attention car enthusiasts: Make your wildest c...
# 4    Classic Cars  Attention car enthusiasts: Make your wildest c...
# ..            ...                                                ...
# 105  Vintage Cars  Our Vintage Car models realistically portray a...
# 106  Vintage Cars  Our Vintage Car models realistically portray a...
# 107  Vintage Cars  Our Vintage Car models realistically portray a...
# 108  Vintage Cars  Our Vintage Car models realistically portray a...
# 109  Vintage Cars  Our Vintage Car models realistically portray a...
#
#     htmlDescription image productCode                       productName  \
# 0              None  None    S10_1949          1952 Alpine Renault 1300
# 1              None  None    S10_4757               1972 Alfa Romeo GTA
# 2              None  None    S10_4962            1962 LanciaA Delta 16V
# 3              None  None    S12_1099                 1968 Ford Mustang
# 4              None  None    S12_1108                 2001 Ferrari Enzo
# ..              ...   ...         ...                               ...
# 105            None  None    S24_3816          1940 Ford Delivery Sedan
# 106            None  None    S24_3969  1936 Mercedes Benz 500k Roadster
# 107            None  None    S24_4258             1936 Chrysler Airflow
# 108            None  None    S32_4289          1928 Ford Phaeton Deluxe
# 109            None  None    S50_1341      1930 Buick Marquette Phaeton
#
#     productScale             productVendor  \
# 0           1:10   Classic Metal Creations
# 1           1:10   Motor City Art Classics
# 2           1:10       Second Gear Diecast
# 3           1:12     Autoart Studio Design
# 4           1:12       Second Gear Diecast
# ..           ...                       ...
# 105         1:24  Carousel DieCast Legends
# 106         1:24         Red Start Diecast
# 107         1:24       Second Gear Diecast
# 108         1:32  Highway 66 Mini Classics
# 109         1:50       Studio M Art Models
#
#                                     productDescription  quantityInStock  \
# 0    Turnable front wheels; steering function; deta...             7305
# 1    Features include: Turnable front wheels; steer...             3252
# 2    Features include: Turnable front wheels; steer...             6791
# 3    Hood, doors and trunk all open to reveal highl...               68
# 4    Turnable front wheels; steering function; deta...             3619
# ..                                                 ...              ...
# 105  Chrome Trim, Chrome Grille, Opening Hood, Open...             6621
# 106  This model features grille-mounted chrome horn...             2081
# 107  Features opening trunk,  working steering syst...             4710
# 108  This model features grille-mounted chrome horn...              136
# 109   Features opening trunk,  working steering system             7062
#
#      buyPrice    MSRP
# 0       98.58  214.30
# 1       85.68  136.00
# 2      103.42  147.74
# 3       95.34  194.57
# 4       95.59  207.80
# ..        ...     ...
# 105     48.64   83.86
# 106     21.75   41.03
# 107     57.46   97.39
# 108     33.02   68.79
# 109     27.06   43.64
#
# [110 rows x 12 columns]

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase. A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 3/Actividad3_BD_Manipulacion"
os.chdir(DIR)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-e05a7c27c0af> in <cell line: 3>()
#       1 import os
#       2 DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 3/Actividad3_BD_Manipulacion"
# ----> 3 os.chdir(DIR)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 3/Actividad3_BD_Manipulacion'

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
#No entendí este ejercicio y no me dió tiempo de trabajarlo más.

# %%
firebase_admin.delete_app(firebase_admin.get_app())
